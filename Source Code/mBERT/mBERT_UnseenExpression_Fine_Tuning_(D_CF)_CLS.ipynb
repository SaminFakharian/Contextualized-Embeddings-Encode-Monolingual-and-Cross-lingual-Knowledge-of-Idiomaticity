# %%
# !pip install transformers==3.0.0
# Out:
# Collecting transformers==3.0.0
#   Downloading https://files.pythonhosted.org/packages/9c/35/1c3f6e62d81f5f0daff1384e6d5e6c5758682a8357ebc765ece2b9def62b/transformers-3.0.0-py3-none-any.whl (754kB)
#      |████████████████████████████████| 757kB 5.9MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.0) (4.41.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.0) (20.9)
# Collecting tokenizers==0.8.0-rc4
#   Downloading https://files.pythonhosted.org/packages/f7/82/0e82a95bd9db2b32569500cc1bb47aa7c4e0f57aa5e35cceba414096917b/tokenizers-0.8.0rc4-cp37-cp37m-manylinux1_x86_64.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 20.3MB/s
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/f5/99/e0808cb947ba10f575839c43e8fafc9cc44e4a7a2c8f79c60db48220a577/sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 36.8MB/s
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/75/ee/67241dc87f266093c533a2d4d3d69438e57d7a90abb216fa076e7d475d4a/sacremoses-0.0.45-py3-none-any.whl (895kB)
#      |████████████████████████████████| 901kB 51.3MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.0) (3.0.12)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.0) (2019.12.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.0) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.0) (1.19.5)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==3.0.0) (2.4.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.0.0) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.0.0) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.0.0) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.0.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.0.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.0.0) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.0.0) (3.0.4)
# Installing collected packages: tokenizers, sentencepiece, sacremoses, transformers
# Successfully installed sacremoses-0.0.45 sentencepiece-0.1.95 tokenizers-0.8.0rc4 transformers-3.0.0

# %%
import random
import os
import re
import math
import time
import datetime
import numpy as np
seed_val = 42
random.seed(seed_val)
np.random.seed(seed_val)
os.environ['PYTHONHASHSEED'] = str(seed_val)
import pylab as pl
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import gensim
from gensim.models.word2vec import Word2Vec
from gensim.models import Word2Vec

import warnings
warnings.filterwarnings('ignore')

from collections import Counter, defaultdict

from sklearn import utils
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import train_test_split,learning_curve, GridSearchCV, cross_val_score, StratifiedKFold,StratifiedShuffleSplit
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix

import torch
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
import torch.nn as nn
from torch.utils.data import TensorDataset, random_split
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler

from tqdm import tqdm
tqdm.pandas(desc="progress-bar")

import transformers as tf
from transformers import get_linear_schedule_with_warmup
from transformers import AdamW
from transformers import AutoModel, BertTokenizerFast,BertModel,BertTokenizer
from transformers import RobertaTokenizer, RobertaModel, AdamW, get_linear_schedule_with_warmup
# %matplotlib inline

from google.colab import drive
from google.colab import files

# %%
import torch
torch.manual_seed(42)
torch.cuda.manual_seed_all(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
import torch.nn as nn
from torch.utils.data import TensorDataset, random_split
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
if torch.cuda.is_available():    

    # Tell PyTorch to use the GPU.    
    device = torch.device("cuda")

    print('There are %d GPU(s) available.' % torch.cuda.device_count())

    print('We will use the GPU:', torch.cuda.get_device_name(0))

# If not...
else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: Tesla V100-SXM2-16GB

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# russian_data=pd.read_excel('./drive/My Drive/Colab Notebooks/dataset/Russian Idioms/sentences_wiki_1404_w_300.xlsx')
dev_train=pd.read_csv('./drive/My Drive/Colab Notebooks/dataset/DEV-Train.csv')
dev_test=pd.read_csv('./drive/My Drive/Colab Notebooks/dataset/DEV-Test.csv')
test_train=pd.read_csv('./drive/My Drive/Colab Notebooks/dataset/TEST-Train.csv')
test_test=pd.read_csv('./drive/My Drive/Colab Notebooks/dataset/TEST-Test.csv')

# russian_data=russian_data.head(1400)
# from sklearn.model_selection import train_test_split

# dev_train, dev_test = train_test_split(russian_data, test_size=0.25,shuffle=True,stratify=russian_data['label'])

dev_train['label'] = dev_train.label.map({'L':0, 'I':1})
# dev_train['isCanon'] = dev_train.isCanon.map({'Not':0, 'C':1})

dev_test['label'] = dev_test.label.map({'L':0, 'I':1})
# dev_test['isCanon'] = dev_test.isCanon.map({'Not':0, 'C':1})

test_train['label'] = test_train.label.map({'L':0, 'I':1})
test_train['isCanon'] = test_train.isCanon.map({'Not':0, 'C':1})

test_test['label'] = test_test.label.map({'L':0, 'I':1})
test_test['isCanon'] = test_test.isCanon.map({'Not':0, 'C':1})

# file_name=dev_train.fileName.unique().tolist()

dev_train=test_train
dev_test=test_test
dev_all=dev_train.append(dev_test)
mwe_name=dev_all.mwe.unique().tolist()
# dev_all=dev_train.append(dev_test)
dev_all=dev_all[dev_all.fileName==0]
# dev_all= russian_data
# dev_all=dev_train.append(dev_test)
# dev_all=dev_all[dev_all.fileName==0]

# %%
import time
import datetime

def format_time(elapsed):
    '''
    Takes a time in seconds and returns a string hh:mm:ss
    '''
    # Round to the nearest second.
    elapsed_rounded = int(round((elapsed)))
    
    # Format as hh:mm:ss
    return str(datetime.timedelta(seconds=elapsed_rounded))

import numpy as np

# Function to calculate the accuracy of our predictions vs labels
def flat_accuracy(preds, labels):
    # pred_flat = np.argmax(preds, axis=1).flatten()
    # labels_flat = labels.flatten()
    return np.sum(preds == labels.numpy()) / len(labels)

def flat_accuracy_num(preds, labels):
    # pred_flat = np.argmax(preds, axis=1).flatten()
    # labels_flat = labels.flatten()
    return np.sum(preds == labels.numpy())

# %%
hidden_data=[]
hidden_dat=[]
cls_hs_input=[]
class Classifier(nn.Module):

    def __init__(self, bert):
      
        super(Classifier, self).__init__()

        self.bert = bert 
        #Network 2
        ########
        self.dropout = nn.Dropout(0.5)
        # relu activation function
        self.relu =  nn.ReLU()
        # dense layer 1
        self.fc1 = nn.Linear(768,512)
        # dense layer 2 (Output layer)
        self.fc2 = nn.Linear(512,2)
        #softmax activation function
        self.softmax = nn.LogSoftmax(dim=1)

    #define the forward pass
    def forward(self, sent_id, mask,stage):
      #pass the inputs to the model  
        # _, cls_hs = self.bert(sent_id, attention_mask=mask)
        output=self.bert(sent_id, attention_mask=mask)
        # cls_hs=output[0][:,0,:]
        # output = output[2]
        cls_hs=output[0][:,0,:]
        if stage=='test':
            cls_hs_input.append(cls_hs.detach().cpu().numpy())
        # print(stage)
        ##########
        x = self.fc1(cls_hs)
        if stage=='test':
            hidden_dat.append(x.detach().cpu().numpy())
        x = self.relu(x)
        x = self.dropout(x)
        # output layer
        if stage=='test':
            hidden_data.append(x.detach().cpu().numpy())
        # print(x)
        x = self.fc2(x)
        # apply softmax activation
        x = self.softmax(x)

        return x

# %%
# function to train the model
def train():
  
  model.train()
#   i=0
  total_loss, total_accuracy = 0, 0
  
  # empty list to save model predictions
  total_preds=[]
  
  # iterate over batches
  for step,batch in enumerate(train_dataloader):
    # print(i)
    # progress update after every 50 batches.
    if step % 10 == 0 and not step == 0:
      print('  Batch {:>5,}  of  {:>5,}.'.format(step, len(train_dataloader)))

    # push the batch to gpu
    batch = [r.to(device) for r in batch]
 
    sent_id, mask, labels = batch

    # clear previously calculated gradients 
    model.zero_grad()        

    # get model predictions for the current batch
    preds = model(sent_id, mask,'train')

    # compute the loss between actual and predicted values
    loss = cross_entropy(preds, labels)

    # add on to the total loss
    total_loss = total_loss + loss.item()

    # backward pass to calculate the gradients
    loss.backward()

    # clip the the gradients to 1.0. It helps in preventing the exploding gradient problem
    torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
    # scheduler = get_linear_schedule_with_warmup(optimizer, 
    #                                                     num_warmup_steps = 0, # Default value in run_glue.py
    #                                                     num_training_steps = total_steps)
    # update parameters
    optimizer.step()
    # scheduler.step()
    # model predictions are stored on GPU. So, push it to CPU
    preds=preds.detach().cpu().numpy()

    # append the model predictions
    total_preds.append(preds)
    # i+=1
  # compute the training loss of the epoch
  avg_loss = total_loss / len(train_dataloader)
  
  # predictions are in the form of (no. of batches, size of batch, no. of classes).
  # reshape the predictions in form of (number of samples, no. of classes)
  total_preds  = np.concatenate(total_preds, axis=0)

  #returns the loss and predictions
  return avg_loss, total_preds

# function for evaluating the model
def evaluate():
  
  print("\nEvaluating...")
  
  # deactivate dropout layers
  model.eval()
#   i=0  
  total_loss, total_accuracy = 0, 0
  
  # empty list to save the model predictions
  total_preds = []

  # iterate over batches
  for step,batch in enumerate(val_dataloader):
    # print(i)
    # Progress update every 50 batches.
    if step % 10 == 0 and not step == 0:
      
      # Calculate elapsed time in minutes.
    #   elapsed = format_time(time.time() - t0)
            
      # Report progress.
      print('  Batch {:>5,}  of  {:>5,}.'.format(step, len(val_dataloader)))

    # push the batch to gpu
    batch = [t.to(device) for t in batch]

    sent_id, mask, labels = batch

    # deactivate autograd
    with torch.no_grad():
    #   print("val_loop:",i)
      # model predictions
      preds = model(sent_id, mask,'evaluate')

      # compute the validation loss between actual and predicted values
      loss = cross_entropy(preds,labels)

      total_loss = total_loss + loss.item()

      preds = preds.detach().cpu().numpy()

      total_preds.append(preds)
    # i+=1
  # compute the validation loss of the epoch
  avg_loss = total_loss / len(val_dataloader) 

  # reshape the predictions in form of (number of samples, no. of classes)
  total_preds  = np.concatenate(total_preds, axis=0)

  return avg_loss, total_preds

# %%
################################################################################
###################################all together#################################
################################################################################
temp_train=pd.DataFrame()
temp_validation=pd.DataFrame()
train_loss=[]
lr_clf_scores_dict={}
svc_clf_scores_dict={}
avg_acc=[]
val_result = []
# learning_rate_range=[2e-5,3e-5,5e-5]
# epoch_range=[2,3,4]
# batch_size_range=[8,16,32]
learning_rate_range=[3e-5]
epoch_range=[4]
batch_size_range=[16]
# i=0
# run=0
# final_result_df=pd.DataFrame()
# final_result_df_le=pd.DataFrame()

i=0
run=0
final_result_df=pd.DataFrame()
final_result_df_le=pd.DataFrame()
random_seeds=[68,96,20,53,91,72,42,14,24,67]
# random_seeds=[42]

for rand_var in random_seeds:
    for er in epoch_range:
      for lrr in learning_rate_range:
        for bsr in batch_size_range:
            for ds in mwe_name:
                print(run)
                run+=1
                print("-------------------------------------------------------")
                print("Start processing for: ",ds)
                temp_train = dev_all[~(dev_all.mwe == ds)]
                temp_test=dev_all[(dev_all.mwe == ds)]

                seed_value = rand_var

                # 1. Set `PYTHONHASHSEED` environment variable at a fixed value
                import os
                os.environ['PYTHONHASHSEED']=str(seed_value)
                # 2. Set `python` built-in pseudo-random generator at a fixed value
                import random
                random.seed(seed_value)
                # 3. Set `numpy` pseudo-random generator at a fixed value
                import numpy as np
                np.random.seed(seed_value)
                import torch
                torch.manual_seed(seed_value)
                torch.cuda.manual_seed_all(seed_value)
                torch.backends.cudnn.deterministic = True
                torch.backends.cudnn.benchmark = False

                # bert = AutoModel.from_pretrained('bert-base-uncased')
                # bert = BertModel.from_pretrained('bert-base-uncased',output_hidden_states=True)
                # # Load the BERT tokenizer
                # tokenizer = BertTokenizerFast.from_pretrained('bert-base-uncased')
                bert = BertModel.from_pretrained('bert-base-multilingual-cased')
                # Load the BERT tokenizer
                tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased')
                # get length of all the messages in the train set
                seq_len = [len(i.split()) for i in dev_train['sentence']]
                # pd.Series(seq_len).hist(bins = 30)
                max_seq_len = 0
                max_len = max_seq_len
                # For every sentence...
                for sent in temp_train['sentence']:
                    # Tokenize the text and add `[CLS]` and `[SEP]` tokens.
                    train_input_ids = tokenizer.encode(sent, add_special_tokens=True)
                    # Update the maximum sentence length.
                    max_seq_len = max(max_seq_len, len(train_input_ids))
                max_seq_len=256
                train_text, val_text, train_labels, val_labels = train_test_split(temp_train['sentence'], temp_train['label'], 
                                                                        random_state=2018, 
                                                                        test_size=0.2, 
                                                                        stratify=temp_train['label'])

                # we will use temp_text and temp_labels to create validation and test set
                test_text =temp_test['sentence']
                test_labels =temp_test['label']
                # tokenize and encode sequences in the training set
                tokens_train = tokenizer.batch_encode_plus(
                    train_text.tolist(),
                    max_length = max_seq_len,
                    pad_to_max_length=True,
                    truncation=True,
                    return_token_type_ids=False
                )

                # tokenize and encode sequences in the validation set
                tokens_val = tokenizer.batch_encode_plus(
                    val_text.tolist(),
                    max_length = max_seq_len,
                    pad_to_max_length=True,
                    truncation=True,
                    return_token_type_ids=False
                )

                # tokenize and encode sequences in the test set
                tokens_test = tokenizer.batch_encode_plus(
                    test_text.tolist(),
                    max_length = max_seq_len,
                    pad_to_max_length=True,
                    truncation=True,
                    return_token_type_ids=False
                )
                # for train set
                train_seq = torch.tensor(tokens_train['input_ids'])
                train_mask = torch.tensor(tokens_train['attention_mask'])
                train_y = torch.tensor(train_labels.tolist())

                # for validation set
                val_seq = torch.tensor(tokens_val['input_ids'])
                val_mask = torch.tensor(tokens_val['attention_mask'])
                val_y = torch.tensor(val_labels.tolist())

                # for test set
                test_seq = torch.tensor(tokens_test['input_ids'])
                test_mask = torch.tensor(tokens_test['attention_mask'])
                test_y = torch.tensor(test_labels.tolist())

                #define a batch size
                batch_size = bsr
                # batch_size = 32

                # wrap tensors
                train_data = TensorDataset(train_seq, train_mask, train_y)

                # sampler for sampling the data during training
                train_sampler = RandomSampler(train_data)

                # dataLoader for train set
                train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_size)

                # wrap tensors
                val_data = TensorDataset(val_seq, val_mask, val_y)

                # sampler for sampling the data during training
                val_sampler = SequentialSampler(val_data)

                # dataLoader for validation set
                val_dataloader = DataLoader(val_data, sampler = val_sampler, batch_size=batch_size)
                # CF_arr=torch.tensor(temp_train.isCanon.to_numpy())
                # CF_arr=torch.reshape(CF_arr,(-1,1))
                # CF_arr=CF_arr.to(device)
                # CF_test_arr=torch.tensor(temp_test.isCanon.to_numpy())
                # CF_test_arr=torch.reshape(CF_test_arr,(-1,1))
                # CF_test_arr=CF_arr.to(device)

                training_stats = []
                training_stats_le = []
                # pass the pre-trained BERT to our define architecture
                model = Classifier(bert)

                # push the model to GPU
                model = model.to(device)
                # optimizer from hugging face transformer
                # define the optimizer
                optimizer = AdamW(model.parameters(), lr = lrr)

                #compute the class weights
                class_wts = compute_class_weight('balanced', np.unique(train_labels), train_labels)
                # convert class weights to tensor
                weights= torch.tensor(class_wts,dtype=torch.float)
                weights = weights.to(device)

                # loss function
                cross_entropy  = nn.NLLLoss(weight=weights) 

                # number of training epochs
                epochs = er
                # set initial loss to infinite
                best_valid_loss = float('inf')

                # empty lists to store training and validation loss of each epoch
                train_losses=[]
                valid_losses=[]

                #for each epoch
                for epoch in range(epochs):
                    
                    print('\nEpoch {:}/{:}'.format(epoch + 1, epochs))
                    
                    #train model
                    train_loss, _ = train()
                    
                    #evaluate model
                    valid_loss, _ = evaluate()
                    
                    #save the best model
                    if valid_loss < best_valid_loss:
                        best_valid_loss = valid_loss
                        torch.save(model.state_dict(), 'saved_weights.pt')
                    
                    # append training and validation loss
                    train_losses.append(train_loss)
                    valid_losses.append(valid_loss)
                    print(f'\nTraining Loss: {train_loss:10.4f}')
                    print(f'Validation Loss: {valid_loss:10.4f}')
                    
                # get predictions for test data
                with torch.no_grad():
                    preds = model(test_seq.to(device), test_mask.to(device),'test')
                    preds = preds.detach().cpu().numpy()
                # model's performance
                preds = np.argmax(preds, axis = 1)
                
                # print(classification_report(test_y, preds))
                total_eval_accuracy_num = 0
                total_eval_accuracy = 0
                total_eval_accuracy = flat_accuracy(preds, test_y)
                total_eval_accuracy_num = flat_accuracy_num(preds, test_y)
                print("Number of True Prediction: {0:10.4f}".format(total_eval_accuracy_num))
                # avg_val_accuracy = total_eval_accuracy / len(test_y)
                print("Accuracy: {0:10.4f}".format(total_eval_accuracy))
                
                TN = 0
                FN = 0
                TP = 0
                FP = 0       
                CM = confusion_matrix(test_y, preds)
                report= classification_report(test_y, preds, digits=3,output_dict=True)
                df = pd.DataFrame(report).transpose()
                print(CM)

                print(report)

            
                TN = CM[0][0]
                if len(CM) == 1:
                    FN = 0
                    TP = 0
                    FP = 0
                else:
                    FN = CM[1][0]
                    TP = CM[1][1]
                    FP = CM[0][1]

                if ((TP+FP) == 0):
                    precision = 0.0
                else:
                    precision=TP/(TP+FP)
                if ((TP+FN) == 0):
                    recall = 0.0
                else:
                    recall=TP/(TP+FN)
                if (precision+recall > 0 ):
                    f1 = (2.0*precision*recall)/(precision+recall)
                else:
                    f1 = 0.0

                # precision_0=report['0']['precision']
                # recall_0=report['0']['recall']
                # f1_0=report['0']['f1-score']
                # support_0=report['0']['support']
                # precision_1=report['1']['precision']
                # recall_1=report['1']['recall']
                # f1_1=report['1']['f1-score']
                # support_1=report['1']['support']
                # macro_avg_f1=report['macro avg']['f1-score']
                # macro_avg_precision=report['macro avg']['precision']
                # macro_avg_recall=report['macro avg']['recall']
                # macro_avg_support=report['macro avg']['support']
                # weighted_avg_f1=report['weighted avg']['f1-score']
                # weighted_avg_precision=report['weighted avg']['precision']
                # weighted_avg_recall=report['weighted avg']['recall']
                # weighted_avg_support=report['weighted avg']['support']

                # val_result.append((rand_var,total_eval_accuracy, total_eval_accuracy_num, len(test_y),
                #                     TN,FN,TP,FP,
                #                     precision_0,recall_0,f1_0,support_0,
                #                     precision_1,recall_1,f1_1,support_1,
                #                     macro_avg_f1,macro_avg_precision,macro_avg_recall,macro_avg_support,
                #                     weighted_avg_f1,weighted_avg_precision,weighted_avg_recall,weighted_avg_support,
                #                     ds, lrr, er, bsr))
                
                val_result.append((rand_var,total_eval_accuracy, total_eval_accuracy_num, len(test_y),
                                    TN,FN,TP,FP,ds, lrr, er, bsr))
                print('DONE.')
validation_df=pd.DataFrame(val_result,columns=['rand_var','accuracy', 'true_labels', 'all_labels',
                                               'TN','FN','TP','FP','file', 'lr', 'e', 'b'])
                
validation_df.to_excel('BERT-UE-W300-English-mbert-randomseeds-TEST.xlsx',index=False)
files.download('BERT-UE-W300-English-mbert-randomseeds-TEST.xlsx')
# Out:
# Streaming output truncated to the last 5000 lines.
# Accuracy:     0.8588
# [[ 5  8]
#  [ 4 68]]
# {'0': {'precision': 0.5555555555555556, 'recall': 0.38461538461538464, 'f1-score': 0.4545454545454546, 'support': 13}, '1': {'precision': 0.8947368421052632, 'recall': 0.9444444444444444, 'f1-score': 0.918918918918919, 'support': 72}, 'accuracy': 0.8588235294117647, 'macro avg': {'precision': 0.7251461988304093, 'recall': 0.6645299145299145, 'f1-score': 0.6867321867321867, 'support': 85}, 'weighted avg': {'precision': 0.8428620571035432, 'recall': 0.8588235294117647, 'f1-score': 0.8478970949559185, 'support': 85}}
# DONE.
# 29
# -------------------------------------------------------
# Start processing for:  make_scene
#
# Epoch 1/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.6223
# Validation Loss:     0.4645
#
# Epoch 2/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.4777
# Validation Loss:     0.2696
#
# Epoch 3/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.2497
# Validation Loss:     0.2911
#
# Epoch 4/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.1156
# Validation Loss:     0.4795
# Number of True Prediction:    30.0000
# Accuracy:     0.6000
# [[ 1 19]
#  [ 1 29]]
# {'0': {'precision': 0.5, 'recall': 0.05, 'f1-score': 0.09090909090909091, 'support': 20}, '1': {'precision': 0.6041666666666666, 'recall': 0.9666666666666667, 'f1-score': 0.7435897435897435, 'support': 30}, 'accuracy': 0.6, 'macro avg': {'precision': 0.5520833333333333, 'recall': 0.5083333333333333, 'f1-score': 0.4172494172494172, 'support': 50}, 'weighted avg': {'precision': 0.5625, 'recall': 0.6, 'f1-score': 0.48251748251748255, 'support': 50}}
# DONE.
# 30
# -------------------------------------------------------
# Start processing for:  have_word
#
# Epoch 1/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.6041
# Validation Loss:     0.6124
#
# Epoch 2/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.4404
# Validation Loss:     0.4653
#
# Epoch 3/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.3648
# Validation Loss:     0.4688
#
# Epoch 4/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.2414
# Validation Loss:     0.5260
# Number of True Prediction:    72.0000
# Accuracy:     0.7912
# [[ 1 10]
#  [ 9 71]]
# {'0': {'precision': 0.1, 'recall': 0.09090909090909091, 'f1-score': 0.09523809523809525, 'support': 11}, '1': {'precision': 0.8765432098765432, 'recall': 0.8875, 'f1-score': 0.8819875776397514, 'support': 80}, 'accuracy': 0.7912087912087912, 'macro avg': {'precision': 0.4882716049382716, 'recall': 0.48920454545454545, 'f1-score': 0.48861283643892334, 'support': 91}, 'weighted avg': {'precision': 0.7826753493420159, 'recall': 0.7912087912087912, 'f1-score': 0.7868859918549359, 'support': 91}}
# DONE.
# 31
# -------------------------------------------------------
# Start processing for:  blow_whistle
#
# Epoch 1/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.6385
# Validation Loss:     0.3993
#
# Epoch 2/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.4073
# Validation Loss:     0.3992
#
# Epoch 3/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.3225
# Validation Loss:     0.4518
#
# Epoch 4/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.1434
# Validation Loss:     0.8305
# Number of True Prediction:    44.0000
# Accuracy:     0.5641
# [[19 32]
#  [ 2 25]]
# {'0': {'precision': 0.9047619047619048, 'recall': 0.37254901960784315, 'f1-score': 0.5277777777777779, 'support': 51}, '1': {'precision': 0.43859649122807015, 'recall': 0.9259259259259259, 'f1-score': 0.5952380952380952, 'support': 27}, 'accuracy': 0.5641025641025641, 'macro avg': {'precision': 0.6716791979949874, 'recall': 0.6492374727668846, 'f1-score': 0.5615079365079365, 'support': 78}, 'weighted avg': {'precision': 0.7433969539232698, 'recall': 0.5641025641025641, 'f1-score': 0.5511294261294262, 'support': 78}}
# DONE.
# 32
# -------------------------------------------------------
# Start processing for:  cut_figure
#
# Epoch 1/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.6239
# Validation Loss:     0.5542
#
# Epoch 2/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.4193
# Validation Loss:     0.3790
#
# Epoch 3/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.3145
# Validation Loss:     0.4006
#
# Epoch 4/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.2041
# Validation Loss:     0.3671
# Number of True Prediction:    33.0000
# Accuracy:     0.7674
# [[ 4  3]
#  [ 7 29]]
# {'0': {'precision': 0.36363636363636365, 'recall': 0.5714285714285714, 'f1-score': 0.4444444444444444, 'support': 7}, '1': {'precision': 0.90625, 'recall': 0.8055555555555556, 'f1-score': 0.8529411764705882, 'support': 36}, 'accuracy': 0.7674418604651163, 'macro avg': {'precision': 0.6349431818181819, 'recall': 0.6884920634920635, 'f1-score': 0.6486928104575163, 'support': 43}, 'weighted avg': {'precision': 0.8179175475687104, 'recall': 0.7674418604651163, 'f1-score': 0.7864417084663323, 'support': 43}}
# DONE.
# 33
# -------------------------------------------------------
# Start processing for:  hit_wall
#
# Epoch 1/4
#   Batch    10  of     28.
#   Batch    20  of     28.
#
# Evaluating...
#
# Training Loss:     0.7059
# Validation Loss:     0.6870
#
# Epoch 2/4
#   Batch    10  of     28.
#   Batch    20  of     28.
#
# Evaluating...
#
# Training Loss:     0.6371
# Validation Loss:     0.5849
#
# Epoch 3/4
#   Batch    10  of     28.
#   Batch    20  of     28.
#
# Evaluating...
#
# Training Loss:     0.4199
# Validation Loss:     0.6799
#
# Epoch 4/4
#   Batch    10  of     28.
#   Batch    20  of     28.
#
# Evaluating...
#
# Training Loss:     0.3657
# Validation Loss:     1.0432
# Number of True Prediction:    46.0000
# Accuracy:     0.7302
# [[39 17]
#  [ 0  7]]
# {'0': {'precision': 1.0, 'recall': 0.6964285714285714, 'f1-score': 0.8210526315789474, 'support': 56}, '1': {'precision': 0.2916666666666667, 'recall': 1.0, 'f1-score': 0.45161290322580644, 'support': 7}, 'accuracy': 0.7301587301587301, 'macro avg': {'precision': 0.6458333333333334, 'recall': 0.8482142857142857, 'f1-score': 0.6363327674023769, 'support': 63}, 'weighted avg': {'precision': 0.9212962962962963, 'recall': 0.7301587301587301, 'f1-score': 0.7800037728730429, 'support': 63}}
# DONE.
# 34
# -------------------------------------------------------
# Start processing for:  get_wind
#
# Epoch 1/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.6514
# Validation Loss:     0.5022
#
# Epoch 2/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.4717
# Validation Loss:     0.3322
#
# Epoch 3/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.3311
# Validation Loss:     0.4463
#
# Epoch 4/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.1926
# Validation Loss:     0.6792
# Number of True Prediction:    24.0000
# Accuracy:     0.8276
# [[14  2]
#  [ 3 10]]
# {'0': {'precision': 0.8235294117647058, 'recall': 0.875, 'f1-score': 0.8484848484848485, 'support': 16}, '1': {'precision': 0.8333333333333334, 'recall': 0.7692307692307693, 'f1-score': 0.8, 'support': 13}, 'accuracy': 0.8275862068965517, 'macro avg': {'precision': 0.8284313725490196, 'recall': 0.8221153846153846, 'f1-score': 0.8242424242424242, 'support': 29}, 'weighted avg': {'precision': 0.8279242731575388, 'recall': 0.8275862068965517, 'f1-score': 0.8267502612330199, 'support': 29}}
# DONE.
# 35
# -------------------------------------------------------
# Start processing for:  make_hay
#
# Epoch 1/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.6866
# Validation Loss:     0.5920
#
# Epoch 2/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.5172
# Validation Loss:     0.4315
#
# Epoch 3/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.3344
# Validation Loss:     0.4539
#
# Epoch 4/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.2111
# Validation Loss:     0.6404
# Number of True Prediction:    12.0000
# Accuracy:     0.7059
# [[6 2]
#  [3 6]]
# {'0': {'precision': 0.6666666666666666, 'recall': 0.75, 'f1-score': 0.7058823529411765, 'support': 8}, '1': {'precision': 0.75, 'recall': 0.6666666666666666, 'f1-score': 0.7058823529411765, 'support': 9}, 'accuracy': 0.7058823529411765, 'macro avg': {'precision': 0.7083333333333333, 'recall': 0.7083333333333333, 'f1-score': 0.7058823529411765, 'support': 17}, 'weighted avg': {'precision': 0.7107843137254901, 'recall': 0.7058823529411765, 'f1-score': 0.7058823529411765, 'support': 17}}
# DONE.
# 36
# -------------------------------------------------------
# Start processing for:  lose_thread
#
# Epoch 1/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.5690
# Validation Loss:     0.7920
#
# Epoch 2/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.3758
# Validation Loss:     0.5472
#
# Epoch 3/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.2006
# Validation Loss:     0.6552
#
# Epoch 4/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.0959
# Validation Loss:     1.0870
# Number of True Prediction:    13.0000
# Accuracy:     0.6500
# [[ 2  0]
#  [ 7 11]]
# {'0': {'precision': 0.2222222222222222, 'recall': 1.0, 'f1-score': 0.3636363636363636, 'support': 2}, '1': {'precision': 1.0, 'recall': 0.6111111111111112, 'f1-score': 0.7586206896551725, 'support': 18}, 'accuracy': 0.65, 'macro avg': {'precision': 0.6111111111111112, 'recall': 0.8055555555555556, 'f1-score': 0.5611285266457681, 'support': 20}, 'weighted avg': {'precision': 0.9222222222222222, 'recall': 0.65, 'f1-score': 0.7191222570532916, 'support': 20}}
# DONE.
# 37
# -------------------------------------------------------
# Start processing for:  get_sack
#
# Epoch 1/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.6623
# Validation Loss:     0.4134
#
# Epoch 2/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.4064
# Validation Loss:     0.3569
#
# Epoch 3/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.2470
# Validation Loss:     0.3865
#
# Epoch 4/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.0844
# Validation Loss:     0.6812
# Number of True Prediction:    23.0000
# Accuracy:     0.4600
# [[ 6  1]
#  [26 17]]
# {'0': {'precision': 0.1875, 'recall': 0.8571428571428571, 'f1-score': 0.30769230769230765, 'support': 7}, '1': {'precision': 0.9444444444444444, 'recall': 0.3953488372093023, 'f1-score': 0.5573770491803278, 'support': 43}, 'accuracy': 0.46, 'macro avg': {'precision': 0.5659722222222222, 'recall': 0.6262458471760797, 'f1-score': 0.43253467843631777, 'support': 50}, 'weighted avg': {'precision': 0.8384722222222222, 'recall': 0.46, 'f1-score': 0.522421185372005, 'support': 50}}
# DONE.
# 38
# -------------------------------------------------------
# Start processing for:  make_hit
#
# Epoch 1/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.6173
# Validation Loss:     0.4901
#
# Epoch 2/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.3876
# Validation Loss:     0.9191
#
# Epoch 3/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.2674
# Validation Loss:     0.4472
#
# Epoch 4/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.1427
# Validation Loss:     0.6533
# Number of True Prediction:     6.0000
# Accuracy:     0.4286
# [[1 8]
#  [0 5]]
# {'0': {'precision': 1.0, 'recall': 0.1111111111111111, 'f1-score': 0.19999999999999998, 'support': 9}, '1': {'precision': 0.38461538461538464, 'recall': 1.0, 'f1-score': 0.5555555555555556, 'support': 5}, 'accuracy': 0.42857142857142855, 'macro avg': {'precision': 0.6923076923076923, 'recall': 0.5555555555555556, 'f1-score': 0.37777777777777777, 'support': 14}, 'weighted avg': {'precision': 0.7802197802197802, 'recall': 0.42857142857142855, 'f1-score': 0.326984126984127, 'support': 14}}
# DONE.
# 39
# -------------------------------------------------------
# Start processing for:  pull_punch
#
# Epoch 1/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.6604
# Validation Loss:     0.5128
#
# Epoch 2/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.4642
# Validation Loss:     0.4931
#
# Epoch 3/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.3079
# Validation Loss:     0.4679
#
# Epoch 4/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.1910
# Validation Loss:     0.7592
# Number of True Prediction:    12.0000
# Accuracy:     0.5455
# [[3 1]
#  [9 9]]
# {'0': {'precision': 0.25, 'recall': 0.75, 'f1-score': 0.375, 'support': 4}, '1': {'precision': 0.9, 'recall': 0.5, 'f1-score': 0.6428571428571429, 'support': 18}, 'accuracy': 0.5454545454545454, 'macro avg': {'precision': 0.575, 'recall': 0.625, 'f1-score': 0.5089285714285714, 'support': 22}, 'weighted avg': {'precision': 0.7818181818181817, 'recall': 0.5454545454545454, 'f1-score': 0.5941558441558442, 'support': 22}}
# DONE.
# 40
# -------------------------------------------------------
# Start processing for:  hold_fire
#
# Epoch 1/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.5867
# Validation Loss:     0.3760
#
# Epoch 2/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.3810
# Validation Loss:     0.4138
#
# Epoch 3/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.2619
# Validation Loss:     0.3953
#
# Epoch 4/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.1244
# Validation Loss:     0.5616
# Number of True Prediction:    18.0000
# Accuracy:     0.7826
# [[12  4]
#  [ 1  6]]
# {'0': {'precision': 0.9230769230769231, 'recall': 0.75, 'f1-score': 0.8275862068965517, 'support': 16}, '1': {'precision': 0.6, 'recall': 0.8571428571428571, 'f1-score': 0.7058823529411764, 'support': 7}, 'accuracy': 0.782608695652174, 'macro avg': {'precision': 0.7615384615384615, 'recall': 0.8035714285714286, 'f1-score': 0.7667342799188641, 'support': 23}, 'weighted avg': {'precision': 0.8247491638795986, 'recall': 0.782608695652174, 'f1-score': 0.7905459035188287, 'support': 23}}
# DONE.
# 41
# -------------------------------------------------------
# Start processing for:  blow_top
#
# Epoch 1/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.7073
# Validation Loss:     0.6791
#
# Epoch 2/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.5502
# Validation Loss:     0.4342
#
# Epoch 3/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.4212
# Validation Loss:     0.4295
#
# Epoch 4/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.2259
# Validation Loss:     0.6506
# Number of True Prediction:    21.0000
# Accuracy:     0.7500
# [[ 4  1]
#  [ 6 17]]
# {'0': {'precision': 0.4, 'recall': 0.8, 'f1-score': 0.5333333333333333, 'support': 5}, '1': {'precision': 0.9444444444444444, 'recall': 0.7391304347826086, 'f1-score': 0.8292682926829269, 'support': 23}, 'accuracy': 0.75, 'macro avg': {'precision': 0.6722222222222223, 'recall': 0.7695652173913043, 'f1-score': 0.6813008130081302, 'support': 28}, 'weighted avg': {'precision': 0.8472222222222222, 'recall': 0.75, 'f1-score': 0.7764227642276423, 'support': 28}}
# DONE.
# 42
# -------------------------------------------------------
# Start processing for:  make_mark
#
# Epoch 1/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.6937
# Validation Loss:     0.6673
#
# Epoch 2/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.5233
# Validation Loss:     0.4639
#
# Epoch 3/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.3526
# Validation Loss:     0.5336
#
# Epoch 4/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.2691
# Validation Loss:     0.5657
# Number of True Prediction:    74.0000
# Accuracy:     0.8706
# [[ 5  8]
#  [ 3 69]]
# {'0': {'precision': 0.625, 'recall': 0.38461538461538464, 'f1-score': 0.4761904761904762, 'support': 13}, '1': {'precision': 0.8961038961038961, 'recall': 0.9583333333333334, 'f1-score': 0.9261744966442952, 'support': 72}, 'accuracy': 0.8705882352941177, 'macro avg': {'precision': 0.760551948051948, 'recall': 0.671474358974359, 'f1-score': 0.7011824864173857, 'support': 85}, 'weighted avg': {'precision': 0.854640947288006, 'recall': 0.8705882352941177, 'f1-score': 0.8573534111631229, 'support': 85}}
# DONE.
# 43
# -------------------------------------------------------
# Start processing for:  make_scene
#
# Epoch 1/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.5963
# Validation Loss:     0.3866
#
# Epoch 2/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.3918
# Validation Loss:     0.3067
#
# Epoch 3/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.2374
# Validation Loss:     0.3590
#
# Epoch 4/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.1318
# Validation Loss:     0.4594
# Number of True Prediction:    31.0000
# Accuracy:     0.6200
# [[ 5 15]
#  [ 4 26]]
# {'0': {'precision': 0.5555555555555556, 'recall': 0.25, 'f1-score': 0.3448275862068966, 'support': 20}, '1': {'precision': 0.6341463414634146, 'recall': 0.8666666666666667, 'f1-score': 0.7323943661971831, 'support': 30}, 'accuracy': 0.62, 'macro avg': {'precision': 0.5948509485094851, 'recall': 0.5583333333333333, 'f1-score': 0.5386109762020399, 'support': 50}, 'weighted avg': {'precision': 0.602710027100271, 'recall': 0.62, 'f1-score': 0.5773676542010685, 'support': 50}}
# DONE.
# 44
# -------------------------------------------------------
# Start processing for:  have_word
#
# Epoch 1/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.5760
# Validation Loss:     0.4020
#
# Epoch 2/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.3441
# Validation Loss:     0.6124
#
# Epoch 3/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.2729
# Validation Loss:     0.3365
#
# Epoch 4/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.1608
# Validation Loss:     0.8900
# Number of True Prediction:    80.0000
# Accuracy:     0.8791
# [[ 1 10]
#  [ 1 79]]
# {'0': {'precision': 0.5, 'recall': 0.09090909090909091, 'f1-score': 0.15384615384615385, 'support': 11}, '1': {'precision': 0.8876404494382022, 'recall': 0.9875, 'f1-score': 0.9349112426035503, 'support': 80}, 'accuracy': 0.8791208791208791, 'macro avg': {'precision': 0.6938202247191011, 'recall': 0.5392045454545454, 'f1-score': 0.5443786982248521, 'support': 91}, 'weighted avg': {'precision': 0.8407828126929251, 'recall': 0.8791208791208791, 'f1-score': 0.8404967813251838, 'support': 91}}
# DONE.
# 45
# -------------------------------------------------------
# Start processing for:  blow_whistle
#
# Epoch 1/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.6057
# Validation Loss:     0.3857
#
# Epoch 2/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.4030
# Validation Loss:     0.3247
#
# Epoch 3/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.1871
# Validation Loss:     0.9520
#
# Epoch 4/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.2294
# Validation Loss:     0.8349
# Number of True Prediction:    56.0000
# Accuracy:     0.7179
# [[31 20]
#  [ 2 25]]
# {'0': {'precision': 0.9393939393939394, 'recall': 0.6078431372549019, 'f1-score': 0.738095238095238, 'support': 51}, '1': {'precision': 0.5555555555555556, 'recall': 0.9259259259259259, 'f1-score': 0.6944444444444444, 'support': 27}, 'accuracy': 0.717948717948718, 'macro avg': {'precision': 0.7474747474747475, 'recall': 0.7668845315904139, 'f1-score': 0.7162698412698412, 'support': 78}, 'weighted avg': {'precision': 0.8065268065268066, 'recall': 0.717948717948718, 'f1-score': 0.722985347985348, 'support': 78}}
# DONE.
# 46
# -------------------------------------------------------
# Start processing for:  cut_figure
#
# Epoch 1/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.6904
# Validation Loss:     0.5398
#
# Epoch 2/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.4186
# Validation Loss:     0.6571
#
# Epoch 3/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.3077
# Validation Loss:     0.2998
#
# Epoch 4/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.1689
# Validation Loss:     0.7182
# Number of True Prediction:    34.0000
# Accuracy:     0.7907
# [[ 2  5]
#  [ 4 32]]
# {'0': {'precision': 0.3333333333333333, 'recall': 0.2857142857142857, 'f1-score': 0.30769230769230765, 'support': 7}, '1': {'precision': 0.8648648648648649, 'recall': 0.8888888888888888, 'f1-score': 0.8767123287671232, 'support': 36}, 'accuracy': 0.7906976744186046, 'macro avg': {'precision': 0.5990990990990991, 'recall': 0.5873015873015872, 'f1-score': 0.5922023182297155, 'support': 43}, 'weighted avg': {'precision': 0.7783364760108947, 'recall': 0.7906976744186046, 'f1-score': 0.7840811625456416, 'support': 43}}
# DONE.
# 47
# -------------------------------------------------------
# Start processing for:  hit_wall
#
# Epoch 1/4
#   Batch    10  of     28.
#   Batch    20  of     28.
#
# Evaluating...
#
# Training Loss:     0.6972
# Validation Loss:     0.6785
#
# Epoch 2/4
#   Batch    10  of     28.
#   Batch    20  of     28.
#
# Evaluating...
#
# Training Loss:     0.5373
# Validation Loss:     0.5629
#
# Epoch 3/4
#   Batch    10  of     28.
#   Batch    20  of     28.
#
# Evaluating...
#
# Training Loss:     0.3921
# Validation Loss:     0.5229
#
# Epoch 4/4
#   Batch    10  of     28.
#   Batch    20  of     28.
#
# Evaluating...
#
# Training Loss:     0.1947
# Validation Loss:     0.9253
# Number of True Prediction:    50.0000
# Accuracy:     0.7937
# [[44 12]
#  [ 1  6]]
# {'0': {'precision': 0.9777777777777777, 'recall': 0.7857142857142857, 'f1-score': 0.8712871287128713, 'support': 56}, '1': {'precision': 0.3333333333333333, 'recall': 0.8571428571428571, 'f1-score': 0.48, 'support': 7}, 'accuracy': 0.7936507936507936, 'macro avg': {'precision': 0.6555555555555556, 'recall': 0.8214285714285714, 'f1-score': 0.6756435643564356, 'support': 63}, 'weighted avg': {'precision': 0.9061728395061729, 'recall': 0.7936507936507936, 'f1-score': 0.8278107810781078, 'support': 63}}
# DONE.
# 48
# -------------------------------------------------------
# Start processing for:  get_wind
#
# Epoch 1/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.6061
# Validation Loss:     0.4397
#
# Epoch 2/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.3484
# Validation Loss:     0.3642
#
# Epoch 3/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.1770
# Validation Loss:     0.3918
#
# Epoch 4/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.1158
# Validation Loss:     0.4156
# Number of True Prediction:    21.0000
# Accuracy:     0.7241
# [[12  4]
#  [ 4  9]]
# {'0': {'precision': 0.75, 'recall': 0.75, 'f1-score': 0.75, 'support': 16}, '1': {'precision': 0.6923076923076923, 'recall': 0.6923076923076923, 'f1-score': 0.6923076923076923, 'support': 13}, 'accuracy': 0.7241379310344828, 'macro avg': {'precision': 0.7211538461538461, 'recall': 0.7211538461538461, 'f1-score': 0.7211538461538461, 'support': 29}, 'weighted avg': {'precision': 0.7241379310344828, 'recall': 0.7241379310344828, 'f1-score': 0.7241379310344828, 'support': 29}}
# DONE.
# 49
# -------------------------------------------------------
# Start processing for:  make_hay
#
# Epoch 1/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.6001
# Validation Loss:     0.4997
#
# Epoch 2/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.4628
# Validation Loss:     0.4189
#
# Epoch 3/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.2559
# Validation Loss:     0.6391
#
# Epoch 4/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.1537
# Validation Loss:     0.6679
# Number of True Prediction:    15.0000
# Accuracy:     0.8824
# [[8 0]
#  [2 7]]
# {'0': {'precision': 0.8, 'recall': 1.0, 'f1-score': 0.888888888888889, 'support': 8}, '1': {'precision': 1.0, 'recall': 0.7777777777777778, 'f1-score': 0.8750000000000001, 'support': 9}, 'accuracy': 0.8823529411764706, 'macro avg': {'precision': 0.9, 'recall': 0.8888888888888888, 'f1-score': 0.8819444444444445, 'support': 17}, 'weighted avg': {'precision': 0.9058823529411765, 'recall': 0.8823529411764706, 'f1-score': 0.8815359477124184, 'support': 17}}
# DONE.
# 50
# -------------------------------------------------------
# Start processing for:  lose_thread
#
# Epoch 1/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.5911
# Validation Loss:     0.5654
#
# Epoch 2/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.3692
# Validation Loss:     0.7063
#
# Epoch 3/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.1982
# Validation Loss:     0.5991
#
# Epoch 4/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.1283
# Validation Loss:     0.9379
# Number of True Prediction:    15.0000
# Accuracy:     0.7500
# [[ 2  0]
#  [ 5 13]]
# {'0': {'precision': 0.2857142857142857, 'recall': 1.0, 'f1-score': 0.4444444444444445, 'support': 2}, '1': {'precision': 1.0, 'recall': 0.7222222222222222, 'f1-score': 0.8387096774193548, 'support': 18}, 'accuracy': 0.75, 'macro avg': {'precision': 0.6428571428571428, 'recall': 0.8611111111111112, 'f1-score': 0.6415770609318996, 'support': 20}, 'weighted avg': {'precision': 0.9285714285714286, 'recall': 0.75, 'f1-score': 0.7992831541218638, 'support': 20}}
# DONE.
# 51
# -------------------------------------------------------
# Start processing for:  get_sack
#
# Epoch 1/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.5650
# Validation Loss:     0.3168
#
# Epoch 2/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.3440
# Validation Loss:     0.6002
#
# Epoch 3/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.2230
# Validation Loss:     0.3582
#
# Epoch 4/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.1068
# Validation Loss:     0.4242
# Number of True Prediction:    34.0000
# Accuracy:     0.6800
# [[ 6  1]
#  [15 28]]
# {'0': {'precision': 0.2857142857142857, 'recall': 0.8571428571428571, 'f1-score': 0.42857142857142855, 'support': 7}, '1': {'precision': 0.9655172413793104, 'recall': 0.6511627906976745, 'f1-score': 0.7777777777777779, 'support': 43}, 'accuracy': 0.68, 'macro avg': {'precision': 0.625615763546798, 'recall': 0.7541528239202657, 'f1-score': 0.6031746031746033, 'support': 50}, 'weighted avg': {'precision': 0.870344827586207, 'recall': 0.68, 'f1-score': 0.728888888888889, 'support': 50}}
# DONE.
# 52
# -------------------------------------------------------
# Start processing for:  make_hit
#
# Epoch 1/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.6840
# Validation Loss:     0.6351
#
# Epoch 2/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.4916
# Validation Loss:     0.4705
#
# Epoch 3/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.2684
# Validation Loss:     0.5371
#
# Epoch 4/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.1716
# Validation Loss:     0.8191
# Number of True Prediction:     8.0000
# Accuracy:     0.5714
# [[3 6]
#  [0 5]]
# {'0': {'precision': 1.0, 'recall': 0.3333333333333333, 'f1-score': 0.5, 'support': 9}, '1': {'precision': 0.45454545454545453, 'recall': 1.0, 'f1-score': 0.625, 'support': 5}, 'accuracy': 0.5714285714285714, 'macro avg': {'precision': 0.7272727272727273, 'recall': 0.6666666666666666, 'f1-score': 0.5625, 'support': 14}, 'weighted avg': {'precision': 0.8051948051948052, 'recall': 0.5714285714285714, 'f1-score': 0.5446428571428571, 'support': 14}}
# DONE.
# 53
# -------------------------------------------------------
# Start processing for:  pull_punch
#
# Epoch 1/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.5659
# Validation Loss:     0.4626
#
# Epoch 2/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.4031
# Validation Loss:     0.4166
#
# Epoch 3/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.2077
# Validation Loss:     0.6013
#
# Epoch 4/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.0884
# Validation Loss:     0.8186
# Number of True Prediction:    13.0000
# Accuracy:     0.5909
# [[ 3  1]
#  [ 8 10]]
# {'0': {'precision': 0.2727272727272727, 'recall': 0.75, 'f1-score': 0.39999999999999997, 'support': 4}, '1': {'precision': 0.9090909090909091, 'recall': 0.5555555555555556, 'f1-score': 0.6896551724137931, 'support': 18}, 'accuracy': 0.5909090909090909, 'macro avg': {'precision': 0.5909090909090908, 'recall': 0.6527777777777778, 'f1-score': 0.5448275862068965, 'support': 22}, 'weighted avg': {'precision': 0.793388429752066, 'recall': 0.5909090909090909, 'f1-score': 0.6369905956112853, 'support': 22}}
# DONE.
# 54
# -------------------------------------------------------
# Start processing for:  hold_fire
#
# Epoch 1/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.6935
# Validation Loss:     0.6504
#
# Epoch 2/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.5480
# Validation Loss:     0.3807
#
# Epoch 3/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.2938
# Validation Loss:     0.5829
#
# Epoch 4/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.1517
# Validation Loss:     0.5713
# Number of True Prediction:    19.0000
# Accuracy:     0.8261
# [[13  3]
#  [ 1  6]]
# {'0': {'precision': 0.9285714285714286, 'recall': 0.8125, 'f1-score': 0.8666666666666666, 'support': 16}, '1': {'precision': 0.6666666666666666, 'recall': 0.8571428571428571, 'f1-score': 0.75, 'support': 7}, 'accuracy': 0.8260869565217391, 'macro avg': {'precision': 0.7976190476190477, 'recall': 0.8348214285714286, 'f1-score': 0.8083333333333333, 'support': 23}, 'weighted avg': {'precision': 0.8488612836438925, 'recall': 0.8260869565217391, 'f1-score': 0.8311594202898551, 'support': 23}}
# DONE.
# 55
# -------------------------------------------------------
# Start processing for:  blow_top
#
# Epoch 1/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.6081
# Validation Loss:     0.6497
#
# Epoch 2/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.4296
# Validation Loss:     0.3610
#
# Epoch 3/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.2196
# Validation Loss:     0.5419
#
# Epoch 4/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.1953
# Validation Loss:     0.6541
# Number of True Prediction:    22.0000
# Accuracy:     0.7857
# [[ 4  1]
#  [ 5 18]]
# {'0': {'precision': 0.4444444444444444, 'recall': 0.8, 'f1-score': 0.5714285714285714, 'support': 5}, '1': {'precision': 0.9473684210526315, 'recall': 0.782608695652174, 'f1-score': 0.8571428571428571, 'support': 23}, 'accuracy': 0.7857142857142857, 'macro avg': {'precision': 0.695906432748538, 'recall': 0.791304347826087, 'f1-score': 0.7142857142857142, 'support': 28}, 'weighted avg': {'precision': 0.8575605680868837, 'recall': 0.7857142857142857, 'f1-score': 0.8061224489795917, 'support': 28}}
# DONE.
# 56
# -------------------------------------------------------
# Start processing for:  make_mark
#
# Epoch 1/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.6920
# Validation Loss:     0.6561
#
# Epoch 2/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.5211
# Validation Loss:     0.5009
#
# Epoch 3/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.3749
# Validation Loss:     0.5521
#
# Epoch 4/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.2257
# Validation Loss:     0.6285
# Number of True Prediction:    65.0000
# Accuracy:     0.7647
# [[10  3]
#  [17 55]]
# {'0': {'precision': 0.37037037037037035, 'recall': 0.7692307692307693, 'f1-score': 0.5, 'support': 13}, '1': {'precision': 0.9482758620689655, 'recall': 0.7638888888888888, 'f1-score': 0.846153846153846, 'support': 72}, 'accuracy': 0.7647058823529411, 'macro avg': {'precision': 0.659323116219668, 'recall': 0.766559829059829, 'f1-score': 0.673076923076923, 'support': 85}, 'weighted avg': {'precision': 0.8598903162797686, 'recall': 0.7647058823529411, 'f1-score': 0.7932126696832578, 'support': 85}}
# DONE.
# 57
# -------------------------------------------------------
# Start processing for:  make_scene
#
# Epoch 1/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.6980
# Validation Loss:     0.6679
#
# Epoch 2/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.6037
# Validation Loss:     0.4029
#
# Epoch 3/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.3364
# Validation Loss:     0.5079
#
# Epoch 4/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.3346
# Validation Loss:     0.5539
# Number of True Prediction:    29.0000
# Accuracy:     0.5800
# [[ 0 20]
#  [ 1 29]]
# {'0': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 20}, '1': {'precision': 0.5918367346938775, 'recall': 0.9666666666666667, 'f1-score': 0.7341772151898733, 'support': 30}, 'accuracy': 0.58, 'macro avg': {'precision': 0.29591836734693877, 'recall': 0.48333333333333334, 'f1-score': 0.36708860759493667, 'support': 50}, 'weighted avg': {'precision': 0.3551020408163265, 'recall': 0.58, 'f1-score': 0.44050632911392396, 'support': 50}}
# DONE.
# 58
# -------------------------------------------------------
# Start processing for:  have_word
#
# Epoch 1/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.5929
# Validation Loss:     0.4232
#
# Epoch 2/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.3254
# Validation Loss:     0.3454
#
# Epoch 3/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.1909
# Validation Loss:     0.4415
#
# Epoch 4/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.1431
# Validation Loss:     0.8808
# Number of True Prediction:    79.0000
# Accuracy:     0.8681
# [[ 1 10]
#  [ 2 78]]
# {'0': {'precision': 0.3333333333333333, 'recall': 0.09090909090909091, 'f1-score': 0.14285714285714288, 'support': 11}, '1': {'precision': 0.8863636363636364, 'recall': 0.975, 'f1-score': 0.9285714285714285, 'support': 80}, 'accuracy': 0.8681318681318682, 'macro avg': {'precision': 0.6098484848484849, 'recall': 0.5329545454545455, 'f1-score': 0.5357142857142857, 'support': 91}, 'weighted avg': {'precision': 0.8195138195138195, 'recall': 0.8681318681318682, 'f1-score': 0.8335949764521192, 'support': 91}}
# DONE.
# 59
# -------------------------------------------------------
# Start processing for:  blow_whistle
#
# Epoch 1/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.6986
# Validation Loss:     0.6593
#
# Epoch 2/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.5889
# Validation Loss:     0.4071
#
# Epoch 3/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.3758
# Validation Loss:     0.2792
#
# Epoch 4/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.2407
# Validation Loss:     0.5466
# Number of True Prediction:    43.0000
# Accuracy:     0.5513
# [[19 32]
#  [ 3 24]]
# {'0': {'precision': 0.8636363636363636, 'recall': 0.37254901960784315, 'f1-score': 0.5205479452054794, 'support': 51}, '1': {'precision': 0.42857142857142855, 'recall': 0.8888888888888888, 'f1-score': 0.5783132530120482, 'support': 27}, 'accuracy': 0.5512820512820513, 'macro avg': {'precision': 0.6461038961038961, 'recall': 0.630718954248366, 'f1-score': 0.5494305991087638, 'support': 78}, 'weighted avg': {'precision': 0.7130369630369631, 'recall': 0.5512820512820513, 'f1-score': 0.5405436286769839, 'support': 78}}
# DONE.
# 60
# -------------------------------------------------------
# Start processing for:  cut_figure
#
# Epoch 1/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.5886
# Validation Loss:     0.4227
#
# Epoch 2/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.4285
# Validation Loss:     0.5058
#
# Epoch 3/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.2775
# Validation Loss:     0.3719
#
# Epoch 4/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.2231
# Validation Loss:     0.7034
# Number of True Prediction:    34.0000
# Accuracy:     0.7907
# [[ 2  5]
#  [ 4 32]]
# {'0': {'precision': 0.3333333333333333, 'recall': 0.2857142857142857, 'f1-score': 0.30769230769230765, 'support': 7}, '1': {'precision': 0.8648648648648649, 'recall': 0.8888888888888888, 'f1-score': 0.8767123287671232, 'support': 36}, 'accuracy': 0.7906976744186046, 'macro avg': {'precision': 0.5990990990990991, 'recall': 0.5873015873015872, 'f1-score': 0.5922023182297155, 'support': 43}, 'weighted avg': {'precision': 0.7783364760108947, 'recall': 0.7906976744186046, 'f1-score': 0.7840811625456416, 'support': 43}}
# DONE.
# 61
# -------------------------------------------------------
# Start processing for:  hit_wall
#
# Epoch 1/4
#   Batch    10  of     28.
#   Batch    20  of     28.
#
# Evaluating...
#
# Training Loss:     0.6336
# Validation Loss:     0.5966
#
# Epoch 2/4
#   Batch    10  of     28.
#   Batch    20  of     28.
#
# Evaluating...
#
# Training Loss:     0.4005
# Validation Loss:     0.6240
#
# Epoch 3/4
#   Batch    10  of     28.
#   Batch    20  of     28.
#
# Evaluating...
#
# Training Loss:     0.2241
# Validation Loss:     0.9734
#
# Epoch 4/4
#   Batch    10  of     28.
#   Batch    20  of     28.
#
# Evaluating...
#
# Training Loss:     0.0998
# Validation Loss:     1.2172
# Number of True Prediction:    51.0000
# Accuracy:     0.8095
# [[44 12]
#  [ 0  7]]
# {'0': {'precision': 1.0, 'recall': 0.7857142857142857, 'f1-score': 0.88, 'support': 56}, '1': {'precision': 0.3684210526315789, 'recall': 1.0, 'f1-score': 0.5384615384615384, 'support': 7}, 'accuracy': 0.8095238095238095, 'macro avg': {'precision': 0.6842105263157895, 'recall': 0.8928571428571428, 'f1-score': 0.7092307692307692, 'support': 63}, 'weighted avg': {'precision': 0.9298245614035088, 'recall': 0.8095238095238095, 'f1-score': 0.842051282051282, 'support': 63}}
# DONE.
# 62
# -------------------------------------------------------
# Start processing for:  get_wind
#
# Epoch 1/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.6104
# Validation Loss:     0.4151
#
# Epoch 2/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.3989
# Validation Loss:     0.3724
#
# Epoch 3/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.2081
# Validation Loss:     0.4016
#
# Epoch 4/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.1439
# Validation Loss:     0.5288
# Number of True Prediction:    22.0000
# Accuracy:     0.7586
# [[13  3]
#  [ 4  9]]
# {'0': {'precision': 0.7647058823529411, 'recall': 0.8125, 'f1-score': 0.787878787878788, 'support': 16}, '1': {'precision': 0.75, 'recall': 0.6923076923076923, 'f1-score': 0.7199999999999999, 'support': 13}, 'accuracy': 0.7586206896551724, 'macro avg': {'precision': 0.7573529411764706, 'recall': 0.7524038461538461, 'f1-score': 0.7539393939393939, 'support': 29}, 'weighted avg': {'precision': 0.7581135902636916, 'recall': 0.7586206896551724, 'f1-score': 0.7574503657262277, 'support': 29}}
# DONE.
# 63
# -------------------------------------------------------
# Start processing for:  make_hay
#
# Epoch 1/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.6832
# Validation Loss:     0.5804
#
# Epoch 2/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.5076
# Validation Loss:     0.4897
#
# Epoch 3/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.3263
# Validation Loss:     0.4004
#
# Epoch 4/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.1835
# Validation Loss:     0.6862
# Number of True Prediction:    13.0000
# Accuracy:     0.7647
# [[8 0]
#  [4 5]]
# {'0': {'precision': 0.6666666666666666, 'recall': 1.0, 'f1-score': 0.8, 'support': 8}, '1': {'precision': 1.0, 'recall': 0.5555555555555556, 'f1-score': 0.7142857142857143, 'support': 9}, 'accuracy': 0.7647058823529411, 'macro avg': {'precision': 0.8333333333333333, 'recall': 0.7777777777777778, 'f1-score': 0.7571428571428571, 'support': 17}, 'weighted avg': {'precision': 0.8431372549019607, 'recall': 0.7647058823529411, 'f1-score': 0.7546218487394958, 'support': 17}}
# DONE.
# 64
# -------------------------------------------------------
# Start processing for:  lose_thread
#
# Epoch 1/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.6326
# Validation Loss:     0.6467
#
# Epoch 2/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.4001
# Validation Loss:     0.5146
#
# Epoch 3/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.1865
# Validation Loss:     0.7932
#
# Epoch 4/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.1440
# Validation Loss:     0.7809
# Number of True Prediction:    12.0000
# Accuracy:     0.6000
# [[ 2  0]
#  [ 8 10]]
# {'0': {'precision': 0.2, 'recall': 1.0, 'f1-score': 0.33333333333333337, 'support': 2}, '1': {'precision': 1.0, 'recall': 0.5555555555555556, 'f1-score': 0.7142857142857143, 'support': 18}, 'accuracy': 0.6, 'macro avg': {'precision': 0.6, 'recall': 0.7777777777777778, 'f1-score': 0.5238095238095238, 'support': 20}, 'weighted avg': {'precision': 0.9199999999999999, 'recall': 0.6, 'f1-score': 0.6761904761904762, 'support': 20}}
# DONE.
# 65
# -------------------------------------------------------
# Start processing for:  get_sack
#
# Epoch 1/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.7093
# Validation Loss:     0.6656
#
# Epoch 2/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.5224
# Validation Loss:     0.2941
#
# Epoch 3/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.3858
# Validation Loss:     0.4050
#
# Epoch 4/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.3109
# Validation Loss:     0.5115
# Number of True Prediction:    38.0000
# Accuracy:     0.7600
# [[ 5  2]
#  [10 33]]
# {'0': {'precision': 0.3333333333333333, 'recall': 0.7142857142857143, 'f1-score': 0.4545454545454545, 'support': 7}, '1': {'precision': 0.9428571428571428, 'recall': 0.7674418604651163, 'f1-score': 0.8461538461538461, 'support': 43}, 'accuracy': 0.76, 'macro avg': {'precision': 0.638095238095238, 'recall': 0.7408637873754154, 'f1-score': 0.6503496503496503, 'support': 50}, 'weighted avg': {'precision': 0.8575238095238096, 'recall': 0.76, 'f1-score': 0.7913286713286714, 'support': 50}}
# DONE.
# 66
# -------------------------------------------------------
# Start processing for:  make_hit
#
# Epoch 1/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.6665
# Validation Loss:     0.5496
#
# Epoch 2/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.4096
# Validation Loss:     0.4498
#
# Epoch 3/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.3264
# Validation Loss:     0.4295
#
# Epoch 4/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.1729
# Validation Loss:     0.7215
# Number of True Prediction:     8.0000
# Accuracy:     0.5714
# [[3 6]
#  [0 5]]
# {'0': {'precision': 1.0, 'recall': 0.3333333333333333, 'f1-score': 0.5, 'support': 9}, '1': {'precision': 0.45454545454545453, 'recall': 1.0, 'f1-score': 0.625, 'support': 5}, 'accuracy': 0.5714285714285714, 'macro avg': {'precision': 0.7272727272727273, 'recall': 0.6666666666666666, 'f1-score': 0.5625, 'support': 14}, 'weighted avg': {'precision': 0.8051948051948052, 'recall': 0.5714285714285714, 'f1-score': 0.5446428571428571, 'support': 14}}
# DONE.
# 67
# -------------------------------------------------------
# Start processing for:  pull_punch
#
# Epoch 1/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.6422
# Validation Loss:     0.4790
#
# Epoch 2/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.3690
# Validation Loss:     0.4864
#
# Epoch 3/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.2211
# Validation Loss:     0.6633
#
# Epoch 4/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.1103
# Validation Loss:     1.5331
# Number of True Prediction:    18.0000
# Accuracy:     0.8182
# [[ 2  2]
#  [ 2 16]]
# {'0': {'precision': 0.5, 'recall': 0.5, 'f1-score': 0.5, 'support': 4}, '1': {'precision': 0.8888888888888888, 'recall': 0.8888888888888888, 'f1-score': 0.8888888888888888, 'support': 18}, 'accuracy': 0.8181818181818182, 'macro avg': {'precision': 0.6944444444444444, 'recall': 0.6944444444444444, 'f1-score': 0.6944444444444444, 'support': 22}, 'weighted avg': {'precision': 0.8181818181818182, 'recall': 0.8181818181818182, 'f1-score': 0.8181818181818182, 'support': 22}}
# DONE.
# 68
# -------------------------------------------------------
# Start processing for:  hold_fire
#
# Epoch 1/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.6459
# Validation Loss:     0.4507
#
# Epoch 2/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.4782
# Validation Loss:     0.3932
#
# Epoch 3/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.2890
# Validation Loss:     0.4830
#
# Epoch 4/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.1456
# Validation Loss:     1.0308
# Number of True Prediction:    16.0000
# Accuracy:     0.6957
# [[10  6]
#  [ 1  6]]
# ...
# Number of True Prediction:    74.0000
# Accuracy:     0.8706
# [[10  3]
#  [ 8 64]]
# {'0': {'precision': 0.5555555555555556, 'recall': 0.7692307692307693, 'f1-score': 0.6451612903225806, 'support': 13}, '1': {'precision': 0.9552238805970149, 'recall': 0.8888888888888888, 'f1-score': 0.9208633093525178, 'support': 72}, 'accuracy': 0.8705882352941177, 'macro avg': {'precision': 0.7553897180762852, 'recall': 0.829059829059829, 'f1-score': 0.7830122998375493, 'support': 85}, 'weighted avg': {'precision': 0.8940981367671448, 'recall': 0.8705882352941177, 'f1-score': 0.8786971182067628, 'support': 85}}
# DONE.
# 127
# -------------------------------------------------------
# Start processing for:  make_scene
#
# Epoch 1/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.5832
# Validation Loss:     0.2824
#
# Epoch 2/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.3436
# Validation Loss:     0.3161
#
# Epoch 3/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.2384
# Validation Loss:     0.3615
#
# Epoch 4/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.0637
# Validation Loss:     0.4124
# Number of True Prediction:    30.0000
# Accuracy:     0.6000
# [[10 10]
#  [10 20]]
# {'0': {'precision': 0.5, 'recall': 0.5, 'f1-score': 0.5, 'support': 20}, '1': {'precision': 0.6666666666666666, 'recall': 0.6666666666666666, 'f1-score': 0.6666666666666666, 'support': 30}, 'accuracy': 0.6, 'macro avg': {'precision': 0.5833333333333333, 'recall': 0.5833333333333333, 'f1-score': 0.5833333333333333, 'support': 50}, 'weighted avg': {'precision': 0.6, 'recall': 0.6, 'f1-score': 0.6, 'support': 50}}
# DONE.
# 128
# -------------------------------------------------------
# Start processing for:  have_word
#
# Epoch 1/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.6788
# Validation Loss:     0.6270
#
# Epoch 2/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.4804
# Validation Loss:     0.6181
#
# Epoch 3/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.3290
# Validation Loss:     0.4727
#
# Epoch 4/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.2731
# Validation Loss:     0.5048
# Number of True Prediction:    78.0000
# Accuracy:     0.8571
# [[ 4  7]
#  [ 6 74]]
# {'0': {'precision': 0.4, 'recall': 0.36363636363636365, 'f1-score': 0.380952380952381, 'support': 11}, '1': {'precision': 0.9135802469135802, 'recall': 0.925, 'f1-score': 0.9192546583850932, 'support': 80}, 'accuracy': 0.8571428571428571, 'macro avg': {'precision': 0.6567901234567901, 'recall': 0.6443181818181818, 'f1-score': 0.6501035196687371, 'support': 91}, 'weighted avg': {'precision': 0.8514991181657848, 'recall': 0.8571428571428571, 'f1-score': 0.8541851523217984, 'support': 91}}
# DONE.
# 129
# -------------------------------------------------------
# Start processing for:  blow_whistle
#
# Epoch 1/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.5951
# Validation Loss:     0.3882
#
# Epoch 2/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.3708
# Validation Loss:     0.4875
#
# Epoch 3/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.2443
# Validation Loss:     0.8602
#
# Epoch 4/4
#   Batch    10  of     27.
#   Batch    20  of     27.
#
# Evaluating...
#
# Training Loss:     0.1463
# Validation Loss:     0.7944
# Number of True Prediction:    52.0000
# Accuracy:     0.6667
# [[27 24]
#  [ 2 25]]
# {'0': {'precision': 0.9310344827586207, 'recall': 0.5294117647058824, 'f1-score': 0.6749999999999999, 'support': 51}, '1': {'precision': 0.5102040816326531, 'recall': 0.9259259259259259, 'f1-score': 0.6578947368421053, 'support': 27}, 'accuracy': 0.6666666666666666, 'macro avg': {'precision': 0.7206192821956369, 'recall': 0.7276688453159041, 'f1-score': 0.6664473684210526, 'support': 78}, 'weighted avg': {'precision': 0.7853624208304011, 'recall': 0.6666666666666666, 'f1-score': 0.669078947368421, 'support': 78}}
# DONE.
# 130
# -------------------------------------------------------
# Start processing for:  cut_figure
#
# Epoch 1/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.5951
# Validation Loss:     0.3984
#
# Epoch 2/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.4237
# Validation Loss:     0.4425
#
# Epoch 3/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.2223
# Validation Loss:     0.5083
#
# Epoch 4/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.1541
# Validation Loss:     0.4667
# Number of True Prediction:    27.0000
# Accuracy:     0.6279
# [[ 5  2]
#  [14 22]]
# {'0': {'precision': 0.2631578947368421, 'recall': 0.7142857142857143, 'f1-score': 0.3846153846153846, 'support': 7}, '1': {'precision': 0.9166666666666666, 'recall': 0.6111111111111112, 'f1-score': 0.7333333333333334, 'support': 36}, 'accuracy': 0.627906976744186, 'macro avg': {'precision': 0.5899122807017544, 'recall': 0.6626984126984128, 'f1-score': 0.558974358974359, 'support': 43}, 'weighted avg': {'precision': 0.8102815177478581, 'recall': 0.627906976744186, 'f1-score': 0.6765652951699465, 'support': 43}}
# DONE.
# 131
# -------------------------------------------------------
# Start processing for:  hit_wall
#
# Epoch 1/4
#   Batch    10  of     28.
#   Batch    20  of     28.
#
# Evaluating...
#
# Training Loss:     0.6579
# Validation Loss:     0.5373
#
# Epoch 2/4
#   Batch    10  of     28.
#   Batch    20  of     28.
#
# Evaluating...
#
# Training Loss:     0.3935
# Validation Loss:     0.5099
#
# Epoch 3/4
#   Batch    10  of     28.
#   Batch    20  of     28.
#
# Evaluating...
#
# Training Loss:     0.1879
# Validation Loss:     0.9813
#
# Epoch 4/4
#   Batch    10  of     28.
#   Batch    20  of     28.
#
# Evaluating...
#
# Training Loss:     0.0424
# Validation Loss:     1.3426
# Number of True Prediction:    54.0000
# Accuracy:     0.8571
# [[47  9]
#  [ 0  7]]
# {'0': {'precision': 1.0, 'recall': 0.8392857142857143, 'f1-score': 0.9126213592233009, 'support': 56}, '1': {'precision': 0.4375, 'recall': 1.0, 'f1-score': 0.6086956521739131, 'support': 7}, 'accuracy': 0.8571428571428571, 'macro avg': {'precision': 0.71875, 'recall': 0.9196428571428572, 'f1-score': 0.760658505698607, 'support': 63}, 'weighted avg': {'precision': 0.9375, 'recall': 0.8571428571428571, 'f1-score': 0.8788518362178134, 'support': 63}}
# DONE.
# 132
# -------------------------------------------------------
# Start processing for:  get_wind
#
# Epoch 1/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.6975
# Validation Loss:     0.6424
#
# Epoch 2/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.5849
# Validation Loss:     0.3924
#
# Epoch 3/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.3625
# Validation Loss:     0.6009
#
# Epoch 4/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.1928
# Validation Loss:     0.4505
# Number of True Prediction:    21.0000
# Accuracy:     0.7241
# [[12  4]
#  [ 4  9]]
# {'0': {'precision': 0.75, 'recall': 0.75, 'f1-score': 0.75, 'support': 16}, '1': {'precision': 0.6923076923076923, 'recall': 0.6923076923076923, 'f1-score': 0.6923076923076923, 'support': 13}, 'accuracy': 0.7241379310344828, 'macro avg': {'precision': 0.7211538461538461, 'recall': 0.7211538461538461, 'f1-score': 0.7211538461538461, 'support': 29}, 'weighted avg': {'precision': 0.7241379310344828, 'recall': 0.7241379310344828, 'f1-score': 0.7241379310344828, 'support': 29}}
# DONE.
# 133
# -------------------------------------------------------
# Start processing for:  make_hay
#
# Epoch 1/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.7035
# Validation Loss:     0.6666
#
# Epoch 2/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.5730
# Validation Loss:     0.5086
#
# Epoch 3/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.3951
# Validation Loss:     0.4105
#
# Epoch 4/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.2574
# Validation Loss:     0.6213
# Number of True Prediction:    14.0000
# Accuracy:     0.8235
# [[6 2]
#  [1 8]]
# {'0': {'precision': 0.8571428571428571, 'recall': 0.75, 'f1-score': 0.7999999999999999, 'support': 8}, '1': {'precision': 0.8, 'recall': 0.8888888888888888, 'f1-score': 0.8421052631578948, 'support': 9}, 'accuracy': 0.8235294117647058, 'macro avg': {'precision': 0.8285714285714285, 'recall': 0.8194444444444444, 'f1-score': 0.8210526315789474, 'support': 17}, 'weighted avg': {'precision': 0.826890756302521, 'recall': 0.8235294117647058, 'f1-score': 0.8222910216718267, 'support': 17}}
# DONE.
# 134
# -------------------------------------------------------
# Start processing for:  lose_thread
#
# Epoch 1/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.6096
# Validation Loss:     0.5238
#
# Epoch 2/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.3620
# Validation Loss:     0.5594
#
# Epoch 3/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.2131
# Validation Loss:     0.9029
#
# Epoch 4/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.1448
# Validation Loss:     1.1205
# Number of True Prediction:    16.0000
# Accuracy:     0.8000
# [[ 2  0]
#  [ 4 14]]
# {'0': {'precision': 0.3333333333333333, 'recall': 1.0, 'f1-score': 0.5, 'support': 2}, '1': {'precision': 1.0, 'recall': 0.7777777777777778, 'f1-score': 0.8750000000000001, 'support': 18}, 'accuracy': 0.8, 'macro avg': {'precision': 0.6666666666666666, 'recall': 0.8888888888888888, 'f1-score': 0.6875, 'support': 20}, 'weighted avg': {'precision': 0.9333333333333333, 'recall': 0.8, 'f1-score': 0.8375, 'support': 20}}
# DONE.
# 135
# -------------------------------------------------------
# Start processing for:  get_sack
#
# Epoch 1/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.6084
# Validation Loss:     0.3833
#
# Epoch 2/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.2848
# Validation Loss:     0.4676
#
# Epoch 3/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.3376
# Validation Loss:     0.4512
#
# Epoch 4/4
#   Batch    10  of     29.
#   Batch    20  of     29.
#
# Evaluating...
#
# Training Loss:     0.1115
# Validation Loss:     0.5714
# Number of True Prediction:    32.0000
# Accuracy:     0.6400
# [[ 7  0]
#  [18 25]]
# {'0': {'precision': 0.28, 'recall': 1.0, 'f1-score': 0.43750000000000006, 'support': 7}, '1': {'precision': 1.0, 'recall': 0.5813953488372093, 'f1-score': 0.7352941176470588, 'support': 43}, 'accuracy': 0.64, 'macro avg': {'precision': 0.64, 'recall': 0.7906976744186047, 'f1-score': 0.5863970588235294, 'support': 50}, 'weighted avg': {'precision': 0.8992, 'recall': 0.64, 'f1-score': 0.6936029411764706, 'support': 50}}
# DONE.
# 136
# -------------------------------------------------------
# Start processing for:  make_hit
#
# Epoch 1/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.5784
# Validation Loss:     0.4552
#
# Epoch 2/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.3436
# Validation Loss:     0.5304
#
# Epoch 3/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.2697
# Validation Loss:     0.4584
#
# Epoch 4/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.1625
# Validation Loss:     0.6220
# Number of True Prediction:    10.0000
# Accuracy:     0.7143
# [[5 4]
#  [0 5]]
# {'0': {'precision': 1.0, 'recall': 0.5555555555555556, 'f1-score': 0.7142857142857143, 'support': 9}, '1': {'precision': 0.5555555555555556, 'recall': 1.0, 'f1-score': 0.7142857142857143, 'support': 5}, 'accuracy': 0.7142857142857143, 'macro avg': {'precision': 0.7777777777777778, 'recall': 0.7777777777777778, 'f1-score': 0.7142857142857143, 'support': 14}, 'weighted avg': {'precision': 0.8412698412698413, 'recall': 0.7142857142857143, 'f1-score': 0.7142857142857143, 'support': 14}}
# DONE.
# 137
# -------------------------------------------------------
# Start processing for:  pull_punch
#
# Epoch 1/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.5978
# Validation Loss:     0.4270
#
# Epoch 2/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.3271
# Validation Loss:     0.4582
#
# Epoch 3/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.2386
# Validation Loss:     0.5878
#
# Epoch 4/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.1495
# Validation Loss:     0.7636
# Number of True Prediction:    17.0000
# Accuracy:     0.7727
# [[ 3  1]
#  [ 4 14]]
# {'0': {'precision': 0.42857142857142855, 'recall': 0.75, 'f1-score': 0.5454545454545454, 'support': 4}, '1': {'precision': 0.9333333333333333, 'recall': 0.7777777777777778, 'f1-score': 0.8484848484848485, 'support': 18}, 'accuracy': 0.7727272727272727, 'macro avg': {'precision': 0.680952380952381, 'recall': 0.7638888888888888, 'f1-score': 0.696969696969697, 'support': 22}, 'weighted avg': {'precision': 0.8415584415584416, 'recall': 0.7727272727272727, 'f1-score': 0.793388429752066, 'support': 22}}
# DONE.
# 138
# -------------------------------------------------------
# Start processing for:  hold_fire
#
# Epoch 1/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.6052
# Validation Loss:     0.4102
#
# Epoch 2/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.4001
# Validation Loss:     0.4104
#
# Epoch 3/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.3197
# Validation Loss:     0.4376
#
# Epoch 4/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.1355
# Validation Loss:     0.6060
# Number of True Prediction:    17.0000
# Accuracy:     0.7391
# [[11  5]
#  [ 1  6]]
# {'0': {'precision': 0.9166666666666666, 'recall': 0.6875, 'f1-score': 0.7857142857142857, 'support': 16}, '1': {'precision': 0.5454545454545454, 'recall': 0.8571428571428571, 'f1-score': 0.6666666666666665, 'support': 7}, 'accuracy': 0.7391304347826086, 'macro avg': {'precision': 0.731060606060606, 'recall': 0.7723214285714286, 'f1-score': 0.726190476190476, 'support': 23}, 'weighted avg': {'precision': 0.8036890645586298, 'recall': 0.7391304347826086, 'f1-score': 0.7494824016563146, 'support': 23}}
# DONE.
# 139
# -------------------------------------------------------
# Start processing for:  blow_top
#
# Epoch 1/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.6285
# Validation Loss:     0.4724
#
# Epoch 2/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.4490
# Validation Loss:     0.3619
#
# Epoch 3/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.2613
# Validation Loss:     0.4894
#
# Epoch 4/4
#   Batch    10  of     30.
#   Batch    20  of     30.
#
# Evaluating...
#
# Training Loss:     0.1909
# Validation Loss:     0.6535
# Number of True Prediction:    24.0000
# Accuracy:     0.8571
# [[ 3  2]
#  [ 2 21]]
# {'0': {'precision': 0.6, 'recall': 0.6, 'f1-score': 0.6, 'support': 5}, '1': {'precision': 0.9130434782608695, 'recall': 0.9130434782608695, 'f1-score': 0.9130434782608695, 'support': 23}, 'accuracy': 0.8571428571428571, 'macro avg': {'precision': 0.7565217391304347, 'recall': 0.7565217391304347, 'f1-score': 0.7565217391304347, 'support': 28}, 'weighted avg': {'precision': 0.8571428571428571, 'recall': 0.8571428571428571, 'f1-score': 0.8571428571428571, 'support': 28}}
# DONE.

# %%
# dev_train=pd.read_csv('./drive/My Drive/Colab Notebooks/dataset/DEV-Train.csv')
# dev_test=pd.read_csv('./drive/My Drive/Colab Notebooks/dataset/DEV-Test.csv')
# test_train=pd.read_csv('./drive/My Drive/Colab Notebooks/dataset/TEST-Train.csv')
# test_test=pd.read_csv('./drive/My Drive/Colab Notebooks/dataset/TEST-Test.csv')
# dev_train=test_train
# dev_test=test_test
# dev_all=dev_train.append(dev_test)
# dev_all=dev_all[dev_all.fileName==0]
# dev_all['label'] = dev_all.label.map({'L':0, 'I':1})
# temp_all=dev_all

# %%
# from sklearn.manifold import TSNE
# fig, axes = plt.subplots(5, 3,figsize=(25,30))
# fig.suptitle('MWEs')
# i=0
# df=pd.DataFrame()
# temp_all['label'] = dev_all.label.map({0:'Literal', 1:'Idiomatic'})
# t= TSNE(learning_rate=50)
# mwe_list=temp_all.mwe.unique()
# palette ={"Idiomatic": "blue", "Literal": "red"}
# for m,ax in zip(mwe_list,axes.flatten()[:15]):
#     df=pd.DataFrame()
#     df['label']=temp_all[temp_all.mwe==m]['label']
#     tsne_features=t.fit_transform(hidden_data[i])
#     df['x']=tsne_features[:,0]
#     df['y']=tsne_features[:,1]
#     sns.scatterplot(ax=ax, x="x",y="y",hue='label',data=df,palette=palette).set_title(m,fontsize=16)
#     i+=1

# plt.show()

# %%
# from sklearn.manifold import TSNE
# all_hidden_data=[]
# for i in range(0,14):
#     for j in range(len(hidden_data[i])):
#         all_hidden_data.append(hidden_data[i][j].tolist())

# fig, axes = plt.subplots(1, 1,figsize=(15,15))
# t= TSNE(learning_rate=50)
# mwe_list=temp_all.mwe.unique()
# df=pd.DataFrame()
# df['label']=temp_all['label']
# df['mwe']=temp_all['mwe']

# tsne_features=t.fit_transform(all_hidden_data)
# df['x']=tsne_features[:,0]
# df['y']=tsne_features[:,1]
# sns.scatterplot(ax= axes,x="x",y="y",hue='mwe',data=df).set_title('AllData',fontsize=16)

# %%
# # from sklearn.manifold import TSNE
# # all_hidden_data=[]
# # for i in range(0,14):
# #     for j in range(len(hidden_data[i])):
# #         all_hidden_data.append(hidden_data[i][j].tolist())
# fig, axes = plt.subplots(1, 1,figsize=(15,15))
# # t= TSNE(learning_rate=50)
# # mwe_list=temp_all.mwe.unique()
# palette ={"Idiomatic": "blue", "Literal": "red"}
# # df=pd.DataFrame()
# # df['label']=temp_all['label']
# # tsne_features=t.fit_transform(all_hidden_data)
# # df['x']=tsne_features[:,0]
# # df['y']=tsne_features[:,1]
# sns.scatterplot(ax= axes,x="x",y="y",hue='label',data=df,palette=palette).set_title('AllData',fontsize=16)

# %%
# # from sklearn.manifold import TSNE
# # all_hidden_data=[]
# # for i in range(0,14):
# #     for j in range(len(hidden_data[i])):
# #         all_hidden_data.append(hidden_data[i][j].tolist())

# # fig, axes = plt.subplots(1, 1,figsize=(20,20))
# # t= TSNE(learning_rate=50)
# # mwe_list=temp_all.mwe.unique()
# # df=pd.DataFrame()
# # df['label']=temp_all['label']
# # df['mwe']=temp_all['mwe']

# # tsne_features=t.fit_transform(all_hidden_data)
# # df['x']=tsne_features[:,0]
# # df['y']=tsne_features[:,1]

# # sns.scatterplot(ax= axes,x="x",y="y",hue='mwe',data=df).set_title('AllData',fontsize=16)

# fig, axes = plt.subplots(1, 1,figsize=(20,20))

# sns.scatterplot(ax= axes,x="x",y="y",hue='mwe',data=df,style='label',s=100).set_title('AllData',fontsize=16)
